# %%
print('hello world')
# Out:
# hello world

# %%
customer_id = 1
customer_name = 'Vanessa Alex'
customer_gender = 'Female'
customer_date_of_birth = '03/17/1997'
driver_license_number = 'e748399212'
auto_policy_number = 7382923319

# %%
print(customer_id + " " + customer_name + " " + customer_date_of_birth + " " + driver_polocy_number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(customer_id + " " + customer_name + " " + customer_date_of_birth + " " + driver_polocy_number)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(str(customer_id) + " " + customer_name + " " + customer_date_of_birth + " " + driver_license_number)
# Out:
# 1 Vanessa Alex 03/17/1997 e748399212
