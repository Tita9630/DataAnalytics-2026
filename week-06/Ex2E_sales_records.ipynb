# %% [markdown]
# # Sales Records Analysis
# ### Author: Tihitina Zergaw
# ### Exercise 2.E Using functions for analyzing data
# This notebook analyzes a small sales dataset using Python functions.
# Each function takes the full dataset as its first argument.

# %%
sales_data = [
 ('Laptop', 'East', 1200.00),
 ('Phone', 'West', 850.00),
 ('Tablet', 'East', 400.00),
 ('Monitor', 'South', 650.00),
 ('Keyboard', 'West', 75.00),
 ('Laptop', 'South', 1150.00),
 ('Phone', 'East', 900.00),
 ('Tablet', 'West', 425.00),
 ('Monitor', 'East', 680.00),
 ('Keyboard', 'South', 80.00),
 ('Laptop', 'West', 1300.00),
 ('Phone', 'West', 820.00),
]

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
 return sum(amt for _, r, amt in data if r == region)  # total amount of sale by region

# %%
print(region_total(sales_data, 'East'))
print(region_total(sales_data, 'West'))
print(region_total(sales_data, 'South'))
# Out:
# 3180.0
# 3470.0
# 1880.0

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    return sum(1 for _, r, amt in data if r == region) # counting records

# %%
print(region_count(sales_data, 'East'))
print(region_count(sales_data, 'West'))
print(region_count(sales_data, 'South'))
# Out:
# 4
# 5
# 3

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region): # Average sale for each region
    count = region_count(data, region)
    if count == 0:
        return 0
    return region_total(data, region) / count

# %%
print(region_average(sales_data, 'East'))
print(region_average(sales_data, 'West'))
print(region_average(sales_data, 'South'))
# Out:
# 795.0
# 694.0
# 626.6666666666666

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def sales_above(data, threshold):
    return [record for record in data if record[2] > threshold] # sales greater than the threshold

# %%
results = sales_above(sales_data, 500) 
for record in results:
    print(record)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Monitor', 'South', 650.0)
# ('Laptop', 'South', 1150.0)
# ('Phone', 'East', 900.0)
# ('Monitor', 'East', 680.0)
# ('Laptop', 'West', 1300.0)
# ('Phone', 'West', 820.0)

# %%
def sales_below(data, threshold):
    return [record for record in data if record[2] < threshold] # sales less than the threshold

# %%
results = sales_below(sales_data, 500) 
for record in results:
    print(record)
# Out:
# ('Tablet', 'East', 400.0)
# ('Keyboard', 'West', 75.0)
# ('Tablet', 'West', 425.0)
# ('Keyboard', 'South', 80.0)

# %% [markdown]
# ## Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(data, key=lambda s: s[2]) # highest sale amount
def bottom_sale(data):
    return min(data, key=lambda s: s[2]) # lowest sale amount

# %%
print(top_sale(sales_data))
print(bottom_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# ### The top sale was a laptop in the west region for $1300.

# %% [markdown]
# ### The bottom sale was a keyboard in the west region for $75.

# %% [markdown]
# ## Lab 6. Apply a discount

# %%
def apply_discount(data, discount_pct):
    return list(map(lambda s: (s[0], s[1], s[2] * (1 - discount_pct)), data)) # applying discount

# %%
discount = apply_discount(sales_data, 0.15)
print("Before discount:")
for record in sales_data[:3]:
    print(record)
print("After discount:")
for record in discount[:3]:
    print(record)
# Out:
# Before discount:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Tablet', 'East', 400.0)
# After discount:
# ('Laptop', 'East', 1020.0)
# ('Phone', 'West', 722.5)
# ('Tablet', 'East', 340.0)

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(r for _, r, amt in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# ### This function helps identify unique values in a dataset for comparison and analysis.

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    region_data = [record for record in data if record[1] == region]
    total = region_total(data, region)
    count = region_count(data, region)
    average = region_average(data, region)
    top = top_sale(region_data)
    print(f"=== {region} Region ===")
    print("Records:", count)
    print("Total sales: $", total)
    print("Average sale: $", average)
    print(f"Top sale: {top[0]} - ${top[2]}")

# %%
region_summary(sales_data, 'East')
# Out:
# === East Region ===
# Records: 4
# Total sales: $ 3180.0
# Average sale: $ 795.0
# Top sale: Laptop -$ 1200.0

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    region_summary(sales_data, region)
# Out:
# === East Region ===
# Records: 4
# Total sales: $ 3180.0
# Average sale: $ 795.0
# Top sale: Laptop - $1200.0
# === South Region ===
# Records: 3
# Total sales: $ 1880.0
# Average sale: $ 626.6666666666666
# Top sale: Laptop - $1150.0
# === West Region ===
# Records: 5
# Total sales: $ 3470.0
# Average sale: $ 694.0
# Top sale: Laptop - $1300.0

# %%
### In this lab, I learned how to use python functions, perform calculations, analyze datasets, find top and bottom sales.
### and finding unique values in order to compare values and more.
